# %%
#Importar librerías
from yucascraper.scrapers.vivienda import lamudi,goodlers,easybroker,metros_cubicos,inmuebles24
import pandas as pd
import time
import random
from matplotlib import pyplot as plt
from sqlalchemy import create_engine
from github import Github, GithubException

# %%
#Se crea función para subir archivo a GitHub
def push_request(df, nombre_archivo,commit_message,carpeta):
    repo_name = "vivi_yuca_result"    
    repo_owner = "claudiodanielpc"
    github={'github': {'token': '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'}}
    #Token de acceso a GitHub
    g = Github(github["github"]["token"])
    #Se establece el repositorio
    repo=g.get_repo("claudiodanielpc/vivi_yuca_result")
    #repo = g.get_repo(f"{repo_owner}/{repo_name}")
    
    try:
        file = repo.get_contents(f"{carpeta}/{nombre_archivo}")
        # Actualizar archivo
        repo.update_file(f"{carpeta}/{nombre_archivo}", commit_message, df.to_csv(index=False,encoding="utf-8-sig"), file.sha, branch="main")
        print("Archivo actualizado con éxito")
    except GithubException as e:
        if e.status == 404:
            # Crear archivo
            repo.create_file(f"{carpeta}/{nombre_archivo}", commit_message, df.to_csv(index=False,encoding="utf-8-sig"), branch="main")
            print("Archivo cargado con éxito")
        else:
            print("Error al cargar archivo")

# %% [markdown]
# #### Scrapeo de datos de los portales inmobiliarios

# %%
# Listado
portales = [goodlers, easybroker, lamudi, metros_cubicos, inmuebles24]
# df vacía
df = pd.DataFrame()

# proceso de scrapeo
for portal in portales:
    try:
        # Tiempo de inicio
        print("Proceso iniciado a las ", time.strftime("%H:%M:%S"),"del día", time.strftime("%d/%m/%y"))
        
        # Ejecuta la función de scraping
        df_portal = portal()  
        df = pd.concat([df, df_portal])
        
        # Records
        print("Número de registros: ", len(df))
        
    except Exception as e:
        # Si ocurre un error, lo imprime
        print(f"Ocurrió un error: {e}")
    
    finally:
        
        print("Proceso terminado a las ", time.strftime("%H:%M:%S"),"del día", time.strftime("%d/%m/%y"))
        print("--------------------------------------------------")
        
        # Sleep for a random time before the next iteration
        time.sleep(random.randint(1, 3))

    
df
# Out:
# Proceso iniciado a las  14:13:54 del día 28/11/23
# Scraping Goodlers:   0%|          | 0/4 [00:00<?, ?it/s]
# Scraping Goodlers: 100%|██████████| 4/4 [00:09<00:00,  2.44s/it]
# Número de registros:  70
# Proceso terminado a las  14:14:05 del día 28/11/23
# --------------------------------------------------
# Proceso iniciado a las  14:14:08 del día 28/11/23
# Scraping Easybroker: 100%|██████████| 100/100 [06:36<00:00,  3.96s/it]
# Número de registros:  2459
# Proceso terminado a las  14:20:44 del día 28/11/23
# --------------------------------------------------
# Proceso iniciado a las  14:20:47 del día 28/11/23
# Scraping Lamudi: 100%|██████████| 100/100 [05:57<00:00,  3.58s/it]
# Número de registros:  5459
# Proceso terminado a las  14:27:37 del día 28/11/23
# --------------------------------------------------
# Proceso iniciado a las  14:27:39 del día 28/11/23
# Scraping MetrosCubicos: 100%|██████████| 40/40 [03:51<00:00,  5.78s/it]
# Ocurrió un error: All arrays must be of the same length
# Proceso terminado a las  14:31:30 del día 28/11/23
# --------------------------------------------------
# Proceso iniciado a las  14:31:33 del día 28/11/23
# Scraping Inmuebles24: 100%|██████████| 70/70 [18:44<00:00, 16.07s/it]
# Número de registros:  6855
# Proceso terminado a las  14:51:02 del día 28/11/23
# --------------------------------------------------
#               desarrollador  \
# 0                   Alameda
# 1           KOBÁ Townhouses
# 2                    Andria
# 3     Kenatta Luxury Villas
# 4         Verna Residencial
# ...                     ...
# 1391                    NaN
# 1392                    NaN
# 1393                    NaN
# 1394                    NaN
# 1395                    NaN
#
#                                                  oferta       fuente  \
# 0                                              chuburna     goodlers
# 1                                         temozon norte     goodlers
# 2                                               sitpach     goodlers
# 3                                         temozon norte     goodlers
# 4                                                conkal     goodlers
# ...                                                 ...          ...
# 1391        venta de casa con vista al lago en altozano  inmuebles24
# 1392              venta de casa lujosa en montes de ame  inmuebles24
# 1393  casa en venta de 3 recamaras en privada avella...  inmuebles24
# 1394         joya escondida en merida. casa habitacion.  inmuebles24
# 1395  casas en venta en privada al norte de merida z...  inmuebles24
#
#           localidad  precio_min  precio_max             fecha_consulta  \
# 0              None   2800000.0   2800000.0 2023-11-28 14:14:05.065584
# 1     temozon norte   3500000.0   3500000.0 2023-11-28 14:14:05.065584
# 2           sitpach   2817000.0   2817000.0 2023-11-28 14:14:05.065584
# 3     temozon norte   4350000.0   4350000.0 2023-11-28 14:14:05.065584
# 4              None   3315000.0   4239000.0 2023-11-28 14:14:05.065584
# ...             ...         ...         ...                        ...
# 1391           None         NaN         NaN 2023-11-28 14:50:58.139634
# 1392  montes de ame         NaN         NaN 2023-11-28 14:50:58.139634
# 1393   las americas         NaN         NaN 2023-11-28 14:50:58.139634
# 1394           None         NaN         NaN 2023-11-28 14:50:58.139634
# 1395           None         NaN         NaN 2023-11-28 14:50:58.139634
#
#           precio  mts_const direccion  ...  lon colonia  \
# 0            NaN        NaN       NaN  ...  NaN     NaN
# 1            NaN        NaN       NaN  ...  NaN     NaN
# 2            NaN        NaN       NaN  ...  NaN     NaN
# 3            NaN        NaN       NaN  ...  NaN     NaN
# 4            NaN        NaN       NaN  ...  NaN     NaN
# ...          ...        ...       ...  ...  ...     ...
# 1391   5350000.0        NaN       NaN  ...  NaN     NaN
# 1392  11000000.0        NaN       NaN  ...  NaN     NaN
# 1393   2250000.0        NaN       NaN  ...  NaN     NaN
# 1394   2300000.0        NaN       NaN  ...  NaN     NaN
# 1395   4390000.0        NaN       NaN  ...  NaN     NaN
#
#                                             descripcion cochera alberca  \
# 0                                                   NaN     NaN     NaN
# 1                                                   NaN     NaN     NaN
# 2                                                   NaN     NaN     NaN
# 3                                                   NaN     NaN     NaN
# 4                                                   NaN     NaN     NaN
# ...                                                 ...     ...     ...
# 1391  Residencia de lujo con vista al lago se encuen...     0.0     0.0
# 1392  Venta de casa lujosa en la colonia Montes de A...     1.0     1.0
# 1393  Casa en Venta de 3 recámaras en Privada Avella...     0.0     0.0
# 1394  ¡Atención amantes de Mérida! En vent una joya ...     0.0     0.0
# 1395  Hermosa casa ubicada en Zentura residencial un...     1.0     1.0
#
#      vigilancia  paddle  casa_club  privada  superficie
# 0           NaN     NaN        NaN      NaN         NaN
# 1           NaN     NaN        NaN      NaN         NaN
# 2           NaN     NaN        NaN      NaN         NaN
# 3           NaN     NaN        NaN      NaN         NaN
# 4           NaN     NaN        NaN      NaN         NaN
# ...         ...     ...        ...      ...         ...
# 1391        1.0     0.0        0.0      1.0         180
# 1392        0.0     0.0        0.0      0.0         820
# 1393        0.0     0.0        0.0      1.0         170
# 1394        0.0     0.0        0.0      0.0         157
# 1395        0.0     0.0        0.0      1.0         279
#
# [6855 rows x 23 columns]

# %%
#Salvar datos sin limpiar
df.to_csv("vivienda_yucatan_sucio.csv",index=False,encoding="utf-8-sig")
push_request(df, "viviyuca_sucia.csv", "Se envía scrapeo sucio", "data")
# Out:
# ---------------------------------------------------------------------------
# BadCredentialsException                   Traceback (most recent call last)
# c:\Users\claud\Documents\GitHub\vivi_yuca_result\pipeline_vivi.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> #Salvar datos sin limpiar
#       <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> df.to_csv("vivienda_yucatan_sucio.csv",index=False,encoding="utf-8-sig")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> push_request(df, "viviyuca_sucia.csv", "Se envía scrapeo sucio", "data")
#
# c:\Users\claud\Documents\GitHub\vivi_yuca_result\pipeline_vivi.ipynb Cell 5 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> g = Github(github["github"]["token"])
#       <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> #Se establece el repositorio
# ----> <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> repo=g.get_repo("claudiodanielpc/vivi_yuca_result")
#      <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> #repo = g.get_repo(f"{repo_owner}/{repo_name}")
#      <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> try:
#
# File c:\Users\claud\miniconda3\lib\site-packages\github\MainClass.py:380, in Github.get_repo(self, full_name_or_id, lazy)
#     378 if lazy:
#     379     return github.Repository.Repository(self.__requester, {}, {"url": url}, completed=False)
# --> 380 headers, data = self.__requester.requestJsonAndCheck("GET", url)
#     381 return github.Repository.Repository(self.__requester, headers, data, completed=True)
#
# File c:\Users\claud\miniconda3\lib\site-packages\github\Requester.py:494, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     486 def requestJsonAndCheck(
#     487     self,
#     488     verb: str,
#    (...)
#     492     input: Optional[Any] = None,
#     493 ) -> Tuple[Dict[str, Any], Any]:
# --> 494     return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#
# File c:\Users\claud\miniconda3\lib\site-packages\github\Requester.py:525, in Requester.__check(self, status, responseHeaders, output)
#     523 data = self.__structuredFromJson(output)
#     524 if status >= 400:
# --> 525     raise self.createException(status, responseHeaders, data)
#     526 return responseHeaders, data
#
# BadCredentialsException: 401 {"message": "Bad credentials", "documentation_url": "https://docs.github.com/rest"}

# %% [markdown]
# #### Limpieza de datos

# %%
def limpia_datos(df):
    df = df.reset_index(drop=True)
   
    #Eliminar registros con precio 0 o nan
    df.loc[df['fuente'] == 'goodlers', 'precio'] = (df['precio_min'] + df['precio_max']) / 2
    df=df[df['precio']>0]
    df=df[df['precio'].notna()]
    #Eliminar registros que en oferta contengan "terreno"
    df=df[~df['oferta'].str.contains('terreno')]
    df=df[~df['oferta'].str.contains('renta')]
    df=df[~df['oferta'].str.contains('remodelar')]
    df=df[~df['oferta'].str.contains('hectareas')]
    #Si la fuente es goodlers, sacar el promedio de precio_min y precio_max y ponerlo en precio
    #Eliminar registros con misma oferta y mismo precio
    df=df.drop_duplicates(subset=['oferta','precio'],keep='first')
    #Crear colloc. Si es nan, poner el dato de la columna que tenga datos, ya sea colonia o localidad
    df['colloc']=df['localidad'].fillna(df['colonia'])
    #Sustituir "benito juarez nte" por "benito juarez norte"
    df['colloc']=df['colloc'].str.replace('benito juarez nte','benito juarez norte')
    #Sustituir "benito juarez ote" por "benito juarez oriente"
    df['colloc']=df['colloc'].str.replace('benito juarez ote','benito juarez oriente')
    df["colloc"]=df["colloc"].str.replace("bellavista","bella vista")
    df["colloc"]=df["colloc"].str.replace("x canatun","xcanatun")

    return df

# %%
df_limpia=limpia_datos(df)
df_limpia
# Out:
#               desarrollador  \
# 0                   Alameda
# 1           KOBÁ Townhouses
# 2                    Andria
# 3     Kenatta Luxury Villas
# 4         Verna Residencial
# ...                     ...
# 6845                    NaN
# 6846                    NaN
# 6849                    NaN
# 6851                    NaN
# 6854                    NaN
#
#                                                  oferta       fuente  \
# 0                                              chuburna     goodlers
# 1                                         temozon norte     goodlers
# 2                                               sitpach     goodlers
# 3                                         temozon norte     goodlers
# 4                                                conkal     goodlers
# ...                                                 ...          ...
# 6845  casa en el centro de merida dos pisos techo al...  inmuebles24
# 6846  casa en venta en fraccionamiento montebello me...  inmuebles24
# 6849  casa en venta en merida en conkal en zona nort...  inmuebles24
# 6851              venta de casa lujosa en montes de ame  inmuebles24
# 6854  casas en venta en privada al norte de merida z...  inmuebles24
#
#           localidad  precio_min  precio_max             fecha_consulta  \
# 0              None   2800000.0   2800000.0 2023-11-28 14:14:05.065584
# 1     temozon norte   3500000.0   3500000.0 2023-11-28 14:14:05.065584
# 2           sitpach   2817000.0   2817000.0 2023-11-28 14:14:05.065584
# 3     temozon norte   4350000.0   4350000.0 2023-11-28 14:14:05.065584
# 4              None   3315000.0   4239000.0 2023-11-28 14:14:05.065584
# ...             ...         ...         ...                        ...
# 6845           None         NaN         NaN 2023-11-28 14:50:58.139634
# 6846     montebello         NaN         NaN 2023-11-28 14:50:58.139634
# 6849           None         NaN         NaN 2023-11-28 14:50:58.139634
# 6851  montes de ame         NaN         NaN 2023-11-28 14:50:58.139634
# 6854           None         NaN         NaN 2023-11-28 14:50:58.139634
#
#           precio  mts_const direccion  ... colonia  \
# 0      2800000.0        NaN       NaN  ...     NaN
# 1      3500000.0        NaN       NaN  ...     NaN
# 2      2817000.0        NaN       NaN  ...     NaN
# 3      4350000.0        NaN       NaN  ...     NaN
# 4      3777000.0        NaN       NaN  ...     NaN
# ...          ...        ...       ...  ...     ...
# 6845   1690000.0        NaN       NaN  ...     NaN
# 6846   4900000.0        NaN       NaN  ...     NaN
# 6849   2880000.0        NaN       NaN  ...     NaN
# 6851  11000000.0        NaN       NaN  ...     NaN
# 6854   4390000.0        NaN       NaN  ...     NaN
#
#                                             descripcion cochera alberca  \
# 0                                                   NaN     NaN     NaN
# 1                                                   NaN     NaN     NaN
# 2                                                   NaN     NaN     NaN
# 3                                                   NaN     NaN     NaN
# 4                                                   NaN     NaN     NaN
# ...                                                 ...     ...     ...
# 6845  Casa en el centro de Mérida con techo alto y d...     0.0     0.0
# 6846  Casa de dos pisos en venta en Fraccionamiento ...     1.0     0.0
# 6849  Casa en venta en Merida, Privada Cumbres Novon...     1.0     0.0
# 6851  Venta de casa lujosa en la colonia Montes de A...     1.0     1.0
# 6854  Hermosa casa ubicada en Zentura residencial un...     1.0     1.0
#
#      vigilancia paddle  casa_club  privada  superficie         colloc
# 0           NaN    NaN        NaN      NaN         NaN            NaN
# 1           NaN    NaN        NaN      NaN         NaN  temozon norte
# 2           NaN    NaN        NaN      NaN         NaN        sitpach
# 3           NaN    NaN        NaN      NaN         NaN  temozon norte
# 4           NaN    NaN        NaN      NaN         NaN            NaN
# ...         ...    ...        ...      ...         ...            ...
# 6845        0.0    0.0        0.0      0.0         132            NaN
# 6846        0.0    0.0        0.0      0.0         220     montebello
# 6849        1.0    0.0        0.0      1.0         225            NaN
# 6851        0.0    0.0        0.0      0.0         820  montes de ame
# 6854        0.0    0.0        0.0      1.0         279            NaN
#
# [5009 rows x 24 columns]

# %%
df_limpia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5009 entries, 0 to 6854
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   desarrollador   70 non-null     object
#  1   oferta          5009 non-null   object
#  2   fuente          5009 non-null   object
#  3   localidad       3265 non-null   object
#  4   precio_min      70 non-null     float64
#  5   precio_max      70 non-null     float64
#  6   fecha_consulta  5009 non-null   datetime64[ns]
#  7   precio          5009 non-null   float64
#  8   mts_const       3602 non-null   float64
#  9   direccion       2267 non-null   object
#  10  bathrooms       4632 non-null   object
#  11  recamaras       4817 non-null   object
#  12  lat             3564 non-null   object
#  13  lon             3564 non-null   object
#  14  colonia         3059 non-null   object
#  15  descripcion     2672 non-null   object
#  16  cochera         2672 non-null   float64
#  17  alberca         2672 non-null   float64
#  18  vigilancia      2672 non-null   float64
#  19  paddle          2672 non-null   float64
#  20  casa_club       2672 non-null   float64
#  21  privada         2672 non-null   float64
#  22  superficie      1149 non-null   object
#  23  colloc          4081 non-null   object
# dtypes: datetime64[ns](1), float64(10), object(13)
# memory usage: 978.3+ KB

# %%
round(len(df_limpia[df_limpia['oferta'].str.contains('venta|vende')])/len(df_limpia)*100,1)
# Out:
# 76.4

# %% [markdown]
# ### Cargar a PostgreSQL

# %%
username = 'postgres'
password = 'olivia14'

# Setting up the connection string for SQLAlchemy
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/postgres')

# %%
df_limpia.to_sql('vivienda_yucatan', engine, if_exists='append', index=False)
print("Datos guardados en la base de datos. Número de registros: ", len(df_limpia))
# Out:
# Datos guardados en la base de datos. Número de registros:  5009

# %%
# # Replace 'table_name' with the actual name of your table
# table_name = 'vivienda_yucatan'

#     # Invoke the table into a pandas DataFrame
# df = pd.read_sql_table(table_name, engine)
# df

# %%
df_limpia.to_csv("viviyuca_limpia.csv",index=False,encoding="utf-8-sig")

# %%
push_request(df_limpia, "viviyuca_limpia.csv", "Se envía primer scrapeo", "data")
# Out:
# ---------------------------------------------------------------------------
# BadCredentialsException                   Traceback (most recent call last)
# c:\Users\claud\Documents\GitHub\vivi_yuca_result\pipeline_vivi.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> push_request(df_limpia, "viviyuca_limpia.csv", "Se envía primer scrapeo", "data")
#
# c:\Users\claud\Documents\GitHub\vivi_yuca_result\pipeline_vivi.ipynb Cell 15 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#X20sZmlsZQ%3D%3D?line=6'>7</a> g = Github(github["github"]["token"])
#       <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> #Se establece el repositorio
# ----> <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> repo=g.get_repo("claudiodanielpc/vivi_yuca_result")
#      <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> #repo = g.get_repo(f"{repo_owner}/{repo_name}")
#      <a href='vscode-notebook-cell:/c%3A/Users/claud/Documents/GitHub/vivi_yuca_result/pipeline_vivi.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> try:
#
# File c:\Users\claud\miniconda3\lib\site-packages\github\MainClass.py:380, in Github.get_repo(self, full_name_or_id, lazy)
#     378 if lazy:
#     379     return github.Repository.Repository(self.__requester, {}, {"url": url}, completed=False)
# --> 380 headers, data = self.__requester.requestJsonAndCheck("GET", url)
#     381 return github.Repository.Repository(self.__requester, headers, data, completed=True)
#
# File c:\Users\claud\miniconda3\lib\site-packages\github\Requester.py:494, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     486 def requestJsonAndCheck(
#     487     self,
#     488     verb: str,
#    (...)
#     492     input: Optional[Any] = None,
#     493 ) -> Tuple[Dict[str, Any], Any]:
# --> 494     return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#
# File c:\Users\claud\miniconda3\lib\site-packages\github\Requester.py:525, in Requester.__check(self, status, responseHeaders, output)
#     523 data = self.__structuredFromJson(output)
#     524 if status >= 400:
# --> 525     raise self.createException(status, responseHeaders, data)
#     526 return responseHeaders, data
#
# BadCredentialsException: 401 {"message": "Bad credentials", "documentation_url": "https://docs.github.com/rest"}

# %%
df_limpia["colloc"].sort_values().unique()
# Out:
# array(['15 de mayo o miguel hidalgo', 'alcala martin', 'aleman',
#        'altabrisa', 'altavista', 'ampliacion la hacienda', 'bella vista',
#        'benito juarez norte', 'benito juarez oriente', 'bojorquez',
#        'brisas del norte', 'buenavista', 'bugambilias', 'cabo norte',
#        'campestre', 'canto', 'carrillo ancona', 'castilla camara',
#        'caucel', 'centro', 'chablekal', 'chichi suarez', 'cholul',
#        'chuburna', 'chuburna de hidalgo', 'chuburna inn', 'chuminopolis',
#        'cinco colonias', 'ciudad caucel', 'ciudad industrial',
#        'club de golf la ceiba', 'cocoyoles', 'conkal', 'cortes sarmiento',
#        'cupules', 'del norte', 'del parque', 'del sur',
#        'delio moreno canton', 'diaz ordaz', 'dolores otero',
#        'dzibilchaltun', 'dzidzilche', 'dzitya', 'el arco',
#        'el conquistador', 'el roble', 'el rosario', 'el triunfo',
#        'emiliano zapata nte', 'emiliano zapata sur', 'emilio portes gil',
#        'esperanza', 'felipe carrillo puerto', 'fidel velazquez',
#        'francisco de montejo', 'francisco de montejo ii',
#        'francisco i madero', 'garcia gineres', 'gonzalo guerrero',
#        'gran san pedro cholul', 'gran santa fe', 'granjas cholul',
#        'inalambrica', 'industrial', 'itzaes', 'itzimna', 'jalapa',
#        'jardines de merida', 'jardines de rejoyada',
#        'jardines de vista alegre', 'jardines del norte', 'jesus carranza',
#        'juan b sosa', 'juan pablo ii', 'kikteil', 'komchen', 'kukulcan',
#        'la ceiba', 'la florida', 'la huerta', 'la rejoyada',
#        'las aguilas (jose maria iturralde)', 'las americas', 'las brisas',
#        'las fincas', 'las margaritas de cholul', 'lazaro cardenas',
#        'lazaro cardenas ote', 'leandro valle', 'lindavista',
#        'loma bonita', 'los almendros', 'los heroes', 'los pinos',
#        'lourdes', 'magnolias', 'maya', 'mejorada', 'melchor ocampo',
#        'mercedes barrera', 'merida centro', 'mexico', 'mexico norte',
#        'mexico oriente', 'mexico poniente', 'miguel aleman',
#        'miguel hidalgo', 'misnebalam', 'monte alban', 'montebello',
#        'montecarlo', 'montecristo', 'montejo', 'monterreal',
#        'montes de ame', 'morelos oriente', 'mulsay', 'nora quintana',
#        'norte', 'nueva aleman', 'nueva mayapan', 'nueva sambula',
#        'nuevo yucatan', 'obrera', 'paraiso', 'paraiso maya',
#        'parque central', 'parque industrial yucatan', 'parque natura',
#        'paseo de las fuentes', 'paseos de opichen',
#        'pedregales de tanlum', 'pensiones', 'petkanche', 'plan de ayala',
#        'plan de ayala sur', 'plan de ayala sur iii', 'platino',
#        'poligono 108', 'prado norte', 'progreso', 'real montejo',
#        'reparto granjas', 'residencial del norte',
#        'residencial del norte ( chenku )', 'residencial floresta',
#        'residencial pensiones iv', 'residencial sol campestre',
#        'residencial valparaiso', 'residencial xcanatun', 'revolucion',
#        'revolucion ( cordemex )', 'roma', 'sacnicte', 'sambula',
#        'san antonio', 'san antonio cinta', 'san antonio hool',
#        'san antonio kaua', 'san antonio ool', 'san antonio xluch',
#        'san antonio xluch ii', 'san antonio xluch iii', 'san carlos',
#        'san cristobal', 'san esteban', 'san gabriel tulipanes',
#        'san jose', 'san jose tecoh', 'san juan', 'san juan bautista',
#        'san luis', 'san miguel', 'san nicolas', 'san pedro cholul',
#        'san pedro uxmal', 'san ramon norte', 'san ramon norte i',
#        'san sebastian', 'santa ana', 'santa cruz', 'santa cruz palomeque',
#        'santa gertrudis copo', 'santa maria', 'santa maria de chuburna',
#        'santa maria yaxche', 'santa rita cholul', 'santa rosa',
#        'santiago', 'serapio rendon', 'sian kaan', 'sitpach',
#        'sodzil norte', 'tamanche', 'tanlum', 'temozon norte', 'terranova',
#        'tixcacal', 'tixcacal opichen', 'tixcuytun', 'valle dorado',
#        'vergel', 'vergel 65', 'vergel ii', 'vicente solis',
#        'villa magna del sur', 'villa moderna', 'villas cholul',
#        'villas de oriente', 'villas del mayab', 'villas del sol',
#        'villas la hacienda', 'vista alegre', 'vista alegre norte',
#        'wallis', 'xcanatun', 'xcumpich', 'xcunya', 'xoclan canto',
#        'xoclan santos', 'xoclan susula', 'yucalpeten', 'yucatan',
#        'yucatan country club', 'zona dorada ii', nan], dtype=object)

# %%
#contar valores únicos de colloc
len(df_limpia["colloc"].unique())
# Out:
# 227
